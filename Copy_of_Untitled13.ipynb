# %% [markdown]
# <a href="https://colab.research.google.com/github/anjunridegreecollege/python-miniprojects/blob/main/Copy_of_Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
age=[]
height=[]
weight=[]
speed=[]
for _ in range (100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
  idata = {'age': age, 'height': height,'weight': weight,'speed':speed}

# %%
idata
# Out:
# {'age': [50,
#   88,
#   98,
#   63,
#   48,
#   58,
#   13,
#   82,
#   50,
#   14,
#   45,
#   53,
#   79,
#   50,
#   99,
#   71,
#   37,
#   24,
#   22,
#   16,
#   53,
#   81,
#   32,
#   23,
#   10,
#   27,
#   78,
#   12,
#   86,
#   61,
#   36,
#   12,
#   96,
#   30,
#   34,
#   18,
#   92,
#   49,
#   3,
#   3,
#   94,
#   27,
#   46,
#   94,
#   72,
#   28,
#   84,
#   9,
#   95,
#   97,
#   53,
#   70,
#   33,
#   87,
#   90,
#   64,
#   31,
#   33,
#   46,
#   28,
#   30,
#   32,
#   21,
#   53,
#   97,
#   4,
#   64,
#   67,
#   53,
#   67,
#   45,
#   18,
#   54,
#   92,
#   94,
#   81,
#   27,
#   37,
#   43,
#   73,
#   13,
#   21,
#   65,
#   12,
#   11,
#   51,
#   15,
#   60,
#   44,
#   74,
#   98,
#   58,
#   88,
#   34,
#   7,
#   21,
#   26,
#   68,
#   44,
#   28],
#  'height': [79,
#   66,
#   74,
#   24,
#   37,
#   31,
#   88,
#   15,
#   40,
#   94,
#   28,
#   64,
#   13,
#   73,
#   3,
#   79,
#   26,
#   65,
#   65,
#   29,
#   33,
#   4,
#   10,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               age      height      weight       speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.670000   53.690000   49.030000   45.300000
# std     28.471164   30.049352   28.313346   29.758455
# min      3.000000    0.000000    0.000000    0.000000
# 25%     27.000000   26.750000   22.750000   16.750000
# 50%     48.500000   59.000000   51.000000   46.000000
# 75%     72.250000   80.750000   69.750000   68.000000
# max     99.000000  100.000000  100.000000   99.000000

# %%
df1[['age','height']]
# Out:
#     age  height
# 0    50      79
# 1    88      66
# 2    98      74
# 3    63      24
# 4    48      37
# ..  ...     ...
# 95   21       0
# 96   26      19
# 97   68      69
# 98   44      39
# 99   28       5
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['age','height']]
# Out:
#    age  height
# 0   50      79
# 3   63      24

# %%
df2 = df1[['age','height']]

# %%
df1.sort_index(ascending=True)
# Out:
#     age  height  weight  speed
# 0    50      79      36     82
# 1    88      66       3      3
# 2    98      74      39      3
# 3    63      24      74     50
# 4    48      37      23      1
# ..  ...     ...     ...    ...
# 95   21       0      11      7
# 96   26      19      67     55
# 97   68      69      63     93
# 98   44      39      46     65
# 99   28       5       0     98
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe ()
# Out:
#              age     height     weight      speed
# count  50.000000  50.000000  50.000000  50.000000
# mean   52.880000  52.460000  51.920000  39.420000
# std    29.528015  29.810428  26.735927  28.695509
# min     3.000000   0.000000   6.000000   0.000000
# 25%    31.250000  26.500000  28.000000  11.250000
# 50%    47.000000  52.000000  53.000000  40.000000
# 75%    82.750000  79.750000  74.250000  60.750000
# max    99.000000  96.000000  99.000000  99.000000

# %%
# Filter
df1['weight']>50
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96     True
# 97     True
# 98    False
# 99    False
# Name: weight, Length: 100, dtype: bool

# %%
# Filter
filter=df1['weight']>50

# %%
df1[filter]
# Out:
#     age  height  weight  speed
# 3    63      24      74     50
# 8    50      40      60     11
# 9    14      94      58     82
# 10   45      28      59     22
# 12   79      13      87     43
# 13   50      73      51     35
# 18   22      65      72     12
# 19   16      29      52     35
# 20   53      33      84      8
# 21   81       4      99     36
# 23   23      99      93     75
# 24   10      84      83     33
# 26   78      63      59     42
# 27   12      32      74     98
# 30   36      83      57     56
# 31   12      58      69     50
# 35   18      70      58     74
# 36   92      76      51     11
# 37   49      55      61     73
# 41   27      53      59     42
# 44   72       2      67     36
# 46   84      93      81     38
# 49   97      14      57     34
# 51   70      13      87      3
# 52   33      68      99      6
# 53   87      47      90     60
# 54   90      49      75      0
# 56   31      52      87     25
# 59   28      19      59     80
# ...

# %%
df1.loc[filter]
# Out:
#     age  height  weight  speed
# 3    63      24      74     50
# 8    50      40      60     11
# 9    14      94      58     82
# 10   45      28      59     22
# 12   79      13      87     43
# 13   50      73      51     35
# 18   22      65      72     12
# 19   16      29      52     35
# 20   53      33      84      8
# 21   81       4      99     36
# 23   23      99      93     75
# 24   10      84      83     33
# 26   78      63      59     42
# 27   12      32      74     98
# 30   36      83      57     56
# 31   12      58      69     50
# 35   18      70      58     74
# 36   92      76      51     11
# 37   49      55      61     73
# 41   27      53      59     42
# 44   72       2      67     36
# 46   84      93      81     38
# 49   97      14      57     34
# 51   70      13      87      3
# 52   33      68      99      6
# 53   87      47      90     60
# 54   90      49      75      0
# 56   31      52      87     25
# 59   28      19      59     80
# ...

# %%
filter1=df1['age']>50

# %%
df1[filter&filter1]
# Out:
#     age  height  weight  speed
# 3    63      24      74     50
# 12   79      13      87     43
# 20   53      33      84      8
# 21   81       4      99     36
# 26   78      63      59     42
# 36   92      76      51     11
# 44   72       2      67     36
# 46   84      93      81     38
# 49   97      14      57     34
# 51   70      13      87      3
# 53   87      47      90     60
# 54   90      49      75      0
# 63   53      84      66     73
# 64   97      23      90     76
# 66   64      85      55     33
# 67   67      65      54     45
# 68   53      69      78     65
# 69   67      89      69     34
# 72   54      75      64     95
# 74   94      44      99     96
# 79   73      97      55     12
# 82   65      96      61     58
# 87   60      39      77     39
# 92   88      95      92     11
# 97   68      69      63     93

# %%
df1.loc[filter&filter1]
# Out:
#     age  height  weight  speed
# 3    63      24      74     50
# 12   79      13      87     43
# 20   53      33      84      8
# 21   81       4      99     36
# 26   78      63      59     42
# 36   92      76      51     11
# 44   72       2      67     36
# 46   84      93      81     38
# 49   97      14      57     34
# 51   70      13      87      3
# 53   87      47      90     60
# 54   90      49      75      0
# 63   53      84      66     73
# 64   97      23      90     76
# 66   64      85      55     33
# 67   67      65      54     45
# 68   53      69      78     65
# 69   67      89      69     34
# 72   54      75      64     95
# 74   94      44      99     96
# 79   73      97      55     12
# 82   65      96      61     58
# 87   60      39      77     39
# 92   88      95      92     11
# 97   68      69      63     93
