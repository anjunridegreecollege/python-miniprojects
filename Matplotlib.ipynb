# %% [markdown]
# <a href="https://colab.research.google.com/github/anjunridegreecollege/python-miniprojects/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import random
x=[]
import random
x=[]
y=[]
[x.append(random.randint(0,25)) for _ in range(10,20)]
[y.append(random.randint(0,25)) for _ in range(10,20)]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
print(x)
# Out:
# [22, 15, 25, 1, 7, 18, 5, 10, 0, 20]

# %%
print(y)
# Out:
# [5, 10, 7, 20, 18, 15, 23, 14, 13, 11]

# %%
plt.plot(x,y)
